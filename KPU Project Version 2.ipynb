# %%
import requests
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys #to be able to click/input
from selenium.webdriver.support.ui import WebDriverWait #wait excplicit
from selenium.webdriver.support import expected_conditions as EC #wait explicit
from selenium.webdriver.common.by import By #find_element
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, ElementClickInterceptedException
from tabulate import tabulate
import pandas as pd
from pandas.errors import InvalidIndexError
import numpy as np

# %% [markdown]
# # *PROFIL DPR SIMPLIFIED*

# %%
#DPR

base_url = "https://sirekap-obj-data.kpu.go.id/pemilu/caleg/partai/{:02d}{:02d}.json"
headers = {"^sec-ch-ua": "^\^Not"}

for i in range(11,93):
    for j in range(1, 10):
        url = base_url.format(i, j)
        response = requests.request("GET", url, headers=headers)
        if response.status_code != 404:
            print(response.text)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\^'
# <>:2: SyntaxWarning: invalid escape sequence '\^'
# C:\Users\Azryll\AppData\Local\Temp\ipykernel_4540\1109169600.py:2: SyntaxWarning: invalid escape sequence '\^'
#   headers = {"^sec-ch-ua": "^\^Not"}
# {
#     "1": {
#         "100121": {
#             "nama": "H. IRMAWAN, S.Sos., M.M.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "100122": {
#             "nama": "M. RAMADHANA RUSLI BINTANG",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "100123": {
#             "nama": "MAHDALENA, S.Hut.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "100124": {
#             "nama": "TEUKU HAMZAH HUSEN, S.E., M.M.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BATAM"
#         },
#         "100125": {
#             "nama": "Tgk. MUJLISAL, S.Ag.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "PIDIE JAYA"
#         },
#         "100126": {
#             "nama": "drh. HASNIDAR",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "100127": {
#             "nama": "Tgk. H. SYARIFUDDIN, M.A.",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA SUBULUSSALAM"
#         }
#     },
#     "2": {
#         "100961": {
#             "nama": "FADHLULLAH, S.E.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "PIDIE"
#         },
#         "100962": {
#             "nama": "Dra. Hj. ZULHAFAH",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "100963": {
#             "nama": "Drs. HASANUDDIN DARJO, M.M.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGGARA"
#         },
#         "100964": {
#             "nama": "Ir. H. MAULISMAN HANAFIAH",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "100965": {
#             "nama": "Ir. MUDDATSTSIR KAMIL",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BEKASI"
#         },
#         "100966": {
#             "nama": "ERLIN, S.E.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "100967": {
#             "nama": "ZAITUN MHD",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH SELATAN"
#         }
#     },
#     "3": {
#         "101801": {
#             "nama": "SOFYAN DAWOOD",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "101802": {
#             "nama": "JAMALUDDIN IDHAM, S.H., M.H.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "NAGAN RAYA"
#         },
#         "101803": {
#             "nama": "YUNIATI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA SUBULUSSALAM"
#         },
#         "101804": {
#             "nama": "RIFKI TAJUDDIN, S.E.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "PIDIE JAYA"
#         },
#         "101805": {
#             "nama": "H. RAMLI MS",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BARAT"
#         },
#         "101806": {
#             "nama": "PUSPITA FIRDA OKTYANI",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "PURBALINGGA"
#         },
#         "101807": {
#             "nama": "H. DAHLAN JAMALUDDIN, S.I.P.",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         }
#     },
#     "4": {
#         "102641": {
#             "nama": "H. T. M. NURLIF",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "102642": {
#             "nama": "H. M. SALIM FAKHRY, S.E., M.M.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGGARA"
#         },
#         "102643": {
#             "nama": "Hj. SAMSIAR, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH TENGGARA"
#         },
#         "102644": {
#             "nama": "Drs. H. T. ZULKARNAINI AMPON BANG",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "NAGAN RAYA"
#         },
#         "102645": {
#             "nama": "Dr. H. M. SALEH.P, S.Pd.I., M.Si.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "102646": {
#             "nama": "NENI RUMIANTI DAULAY, S.E.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "102647": {
#             "nama": "T. M. ALI TAR",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         }
#     },
#     "5": {
#         "103481": {
#             "nama": "Dr. TEUKU TAUFIQULHADI, M.Si.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "103482": {
#             "nama": "H. MUSLIM AYUB, S.H., M.M.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "103483": {
#             "nama": "Dra. Hj. MEDIATI HAFNI HANUM, S.H., M.Kn., CPM.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "103484": {
#             "nama": "TEUNGKU RAZUAN, S.H.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "103485": {
#             "nama": "T. ISKANDAR DAOD, S.E., M.Si.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BARAT"
#         },
#         "103486": {
#             "nama": "CUT SRI MAINITA",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "103487": {
#             "nama": "SUPRIJAL YUSUF, S.H.",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "6": {
#         "104321": {
#             "nama": "Habibi Inseun",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "104322": {
#             "nama": "Mahadi Manik, S.Si., M.Si.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "104323": {
#             "nama": "Rosmana Dewi",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "104324": {
#             "nama": "Sayed Masykur, S.T.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "104325": {
#             "nama": "Zarlina",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "104326": {
#             "nama": "Hariyanto Latuheru",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KARAWANG"
#         },
#         "104327": {
#             "nama": "Siti Sundari",
#             "nomor_urut": 7,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BEKASI"
#         }
#     },
#     "7": {
#         "105161": {
#             "nama": "AZMI FAJRI USMAN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA PUSAT"
#         },
#         "105162": {
#             "nama": "TGK KHALIDI AL-DJADAMI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BARAT DAYA"
#         },
#         "105163": {
#             "nama": "KASUMIYATI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH TENGGARA"
#         },
#         "105164": {
#             "nama": "NASRUDDIN AWL",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "105165": {
#             "nama": "EDY SUPENO",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "105166": {
#             "nama": "FANIA VIVI HIKMAWATI, S.E.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BEKASI"
#         },
#         "105167": {
#             "nama": "MOHARRIADI",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         }
#     },
#     "8": {
#         "106001": {
#             "nama": "GHUFRAN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "106002": {
#             "nama": "RAFLY KANDE",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "106003": {
#             "nama": "FRIESKA INDAH SARI, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "106004": {
#             "nama": "BUHARI SELIAN",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGGARA"
#         },
#         "106005": {
#             "nama": "SAID MUSTAJAB, S.Sos.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "106006": {
#             "nama": "Ns. SINTA NELYSA, S.Kep.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "106007": {
#             "nama": "SRI WAHYUNI",
#             "nomor_urut": 7,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH BESAR"
#         }
#     },
#     "9": {
#         "106841": {
#             "nama": "YUDI KURNIA, S.E.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "106842": {
#             "nama": "AMRINUR OKTAJAYA",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA TANGERANG SELATAN"
#         },
#         "106843": {
#             "nama": "Hj. SERI PERAINI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "106844": {
#             "nama": "YANTI OCTAVIA",
#             "nomor_urut": 4,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA PUSAT"
#         },
#         "106845": {
#             "nama": "NELY INDRAWATI",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "106846": {
#             "nama": "NOLA NOLIA",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "10": {
#         "107681": {
#             "nama": "Prof. Dr. BACHTIAR ALY, M.A.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "107682": {
#             "nama": "Dr. H. ASFIFUDDIN, S.H., M.H.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA BARAT"
#         },
#         "107683": {
#             "nama": "FITRIAH ISPANDI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "107684": {
#             "nama": "AL AMIN, S.H.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BARAT DAYA"
#         },
#         "107685": {
#             "nama": "INTAN KHAIRANI",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "107686": {
#             "nama": "SRI ARIANA NINGSIH",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "107687": {
#             "nama": "ADNAN YACOB, S.E.",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "11": {
#         "108521": {
#             "nama": "CHAIDIR FURRAZI NUR",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "108522": {
#             "nama": "PUTRI CHOIRUN NISYA",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "108523": {
#             "nama": "EGI KURNIA PUTRA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "LAMPUNG TIMUR"
#         },
#         "108524": {
#             "nama": "BENING LARASATI",
#             "nomor_urut": 4,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "LAMPUNG TIMUR"
#         },
#         "108525": {
#             "nama": "T. ISKANDAR, S.T.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "108526": {
#             "nama": "SETYANI LARASATI",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "PANDEGLANG"
#         }
#     },
#     "12": {
#         "109361": {
#             "nama": "H. NAZARUDDIN DEK GAM",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "109362": {
#             "nama": "MOHD. ALFATAH, S.Ag.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "NAGAN RAYA"
#         },
#         "109363": {
#             "nama": "Ir. Hj. FERRY SORAYA, M.S.I.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "109364": {
#             "nama": "DEWI MARLINA",
#             "nomor_urut": 4,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "109365": {
#             "nama": "MUCHLIS ZULKIFLI, S.T., M.H.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "109366": {
#             "nama": "GITA ISNA YUNITA, S.E.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "109367": {
#             "nama": "ZULFITRI ARIFIN",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA PUSAT"
#         }
#     },
#     "13": {
#         "110201": {
#             "nama": "H. ERLI HASIM, S.H., S.Ag., M.I.Kom.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "SIMEULUE"
#         },
#         "110202": {
#             "nama": "Dr. TGK. H. MUHAMMAD YUS",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110203": {
#             "nama": "NURATIAH HANIM, A.Md.Kep.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA TANGERANG SELATAN"
#         },
#         "110204": {
#             "nama": "SALAWATI DAHLAN M.S., S.E.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110205": {
#             "nama": "HAMZAH, S.Sos.I.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110206": {
#             "nama": "Heri Ramunandar, S.H.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110207": {
#             "nama": "SALAMUN, S.E.",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         }
#     },
#     "14": {
#         "111041": {
#             "nama": "H. TEUKU RIEFKY HARSYA",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "111042": {
#             "nama": "H. T. IBRAHIM, S.T., M.M.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "111043": {
#             "nama": "NURHAYATI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "GAYO LUES"
#         },
#         "111044": {
#             "nama": "KHAIRULLAH",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "111045": {
#             "nama": "Tgk. HARMEN NURIQMAR, S.S.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BARAT"
#         },
#         "111046": {
#             "nama": "RIZQA ZANIA",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "111047": {
#             "nama": "TEUKU RASSYA I. PASYA",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         }
#     },
#     "15": {
#         "111881": {
#             "nama": "Qausar Harta Yudana",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "111882": {
#             "nama": "AL-QUDRI, S.T.P.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA SUBULUSSALAM"
#         },
#         "111883": {
#             "nama": "Ercut Nova Sari",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "111884": {
#             "nama": "ARIEF MARTHA RAHADYAN",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA DENPASAR"
#         },
#         "111885": {
#             "nama": "Ismaidi",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "111886": {
#             "nama": "Suci Nur Maizaroh",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "PACITAN"
#         },
#         "111887": {
#             "nama": "SLAMET SATYAWATI",
#             "nomor_urut": 7,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA SURAKARTA"
#         }
#     },
#     "16": {
#         "112721": {
#             "nama": "Mayjen. TNI (Purn.) ABDUL HAFIL FUDDIN, S.H., S.I.P., M.H.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA PUSAT"
#         },
#         "112722": {
#             "nama": "AZWAR RAMLI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "112723": {
#             "nama": "INTAN MONIKA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "SIMEULUE"
#         },
#         "112724": {
#             "nama": "DENY ZULFIKAR",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "112725": {
#             "nama": "Drs. ABDON SIAGIAN",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "112726": {
#             "nama": "SIWI ASRI MOPRIRATNA",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "112727": {
#             "nama": "DWI AGUS SETIYORINI",
#             "nomor_urut": 7,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         }
#     },
#     "17": {
#         "113561": {
#             "nama": "AMRI M. ALI",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "113562": {
#             "nama": "ILLIZA SA'ADUDDIN DJAMAL, S.E.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "113563": {
#             "nama": "HILMAN ISMAIL METAREUM, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA BARAT"
#         },
#         "113564": {
#             "nama": "H. ANSARI IDRUS SAMBO, S.H.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA SUBULUSSALAM"
#         },
#         "113565": {
#             "nama": "HARMANIAR",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "NAGAN RAYA"
#         },
#         "113566": {
#             "nama": "SAID SAIFUL AL MAHDALI",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH SELATAN"
#         },
#         "113567": {
#             "nama": "CUT RATNAWATI",
#             "nomor_urut": 7,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "24": {
#         "114401": {
#             "nama": "H. JAMAI SUNI, S.E., M.M.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "114402": {
#             "nama": "H. ANAS BIDIN NYAK SYECH, S.Ag.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "114403": {
#             "nama": "CUT EVITA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "114404": {
#             "nama": "Drs. USTAZ ARSYAD AHJON",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "114405": {
#             "nama": "Drs. SAIFUDDIN SAMIN",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "114406": {
#             "nama": "FARIDAH, S.E.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "114407": {
#             "nama": "EFFRIDANDA M., S.E.",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     }
# }
# {
#     "1": {
#         "100101": {
#             "nama": "H. RUSLAN DAUD (HRD)",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BIREUEN"
#         },
#         "100102": {
#             "nama": "MUHAMMAD ADAM, M.Ed.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BOGOR"
#         },
#         "100103": {
#             "nama": "ANA FITRIA SARI PINEM, S.H., M.Kn.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH TENGAH"
#         },
#         "100104": {
#             "nama": "H. DARKASYI, S.H.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BIREUEN"
#         },
#         "100105": {
#             "nama": "SUMADI ARSYAH",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH UTARA"
#         },
#         "100106": {
#             "nama": "ARINI ARISKA, A.Md.Keb",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH TAMIANG"
#         }
#     },
#     "2": {
#         "100941": {
#             "nama": "Ir. H. T. A. KHALID, M.M.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "100942": {
#             "nama": "FADLI TRI HARTONO, S.Si., M.P.A.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BEKASI"
#         },
#         "100943": {
#             "nama": "CUT PUTEH",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "100944": {
#             "nama": "H. FACHRUL RAZI, M.I.P.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LHOKSEUMAWE"
#         },
#         "100945": {
#             "nama": "T. ZAINAL ABIDIN, S.Pd.I., M.H.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "100946": {
#             "nama": "DEWI KARTIKA, S.H.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH TAMIANG"
#         }
#     },
#     "3": {
#         "101781": {
#             "nama": "ARWIN MEGA",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGAH"
#         },
#         "101782": {
#             "nama": "HANAFIAH",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "PIDIE"
#         },
#         "101783": {
#             "nama": "DWI AYU MARGASARI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "PEMALANG"
#         },
#         "101784": {
#             "nama": "M. SALADIN AKBAR, S.ST.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "101785": {
#             "nama": "MAS ADI M",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "101786": {
#             "nama": "DWI KRISTINAWATI",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "SUKOHARJO"
#         }
#     },
#     "4": {
#         "102621": {
#             "nama": "H. ILHAM PANGESTU",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "102622": {
#             "nama": "H. SAYED FUAD ZAKARIA, S.E.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA TANGERANG SELATAN"
#         },
#         "102623": {
#             "nama": "CUT RIZKA SEPTIANI, S.I.Kom., M.Si.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "102624": {
#             "nama": "MOHD AMIN",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BENER MERIAH"
#         },
#         "102625": {
#             "nama": "drh. NURAINI MAIDA",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LHOKSEUMAWE"
#         },
#         "102626": {
#             "nama": "SAMSUL BAHRI TIYONG",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BIREUEN"
#         }
#     },
#     "5": {
#         "103461": {
#             "nama": "Prof. Dr. Ir. H. ABDULLAH PUTEH, M.Si.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "103462": {
#             "nama": "Ir. H. NASARUDDIN, M.M.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGAH"
#         },
#         "103463": {
#             "nama": "Hj. ISMANIAR, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "103464": {
#             "nama": "AGUS HIDAYAT THAIB, S.E.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH UTARA"
#         },
#         "103465": {
#             "nama": "IRSAN SOSIAWAN, M.B.A.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA PUSAT"
#         },
#         "103466": {
#             "nama": "Hj. FATIMAH",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LANGSA"
#         }
#     },
#     "6": {
#         "104301": {
#             "nama": "Drs. Agus Syahputra",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "104302": {
#             "nama": "Fitria Ningsih",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BEKASI"
#         },
#         "104303": {
#             "nama": "Marjuki",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "104304": {
#             "nama": "Abdi Hasan Subari",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BEKASI"
#         },
#         "104305": {
#             "nama": "Arianingsih",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BEKASI"
#         },
#         "104306": {
#             "nama": "Tukimin",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         }
#     },
#     "7": {
#         "105141": {
#             "nama": "H. FUADY, S.T., M.Si.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "105142": {
#             "nama": "FAUZI RAMADHAN",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGAH"
#         },
#         "105143": {
#             "nama": "SARI DEWI, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BIREUEN"
#         },
#         "105144": {
#             "nama": "ZULKIFLI USMAN",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA PUSAT"
#         },
#         "105145": {
#             "nama": "EGA SURYANINGSIH",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LANGSA"
#         }
#     },
#     "8": {
#         "105981": {
#             "nama": "M. NASIR DJAMIL, M.Si.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "105982": {
#             "nama": "TENGKU INSYAFUDDIN, S.T.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TAMIANG"
#         },
#         "105983": {
#             "nama": "ANANDA FILDZA ALIFA, S.Sos.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BIREUEN"
#         },
#         "105984": {
#             "nama": "dr. EDDI JUNAIDI, Sp.OG., S.H., M.Kes.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "105985": {
#             "nama": "AIDIL FAN",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "105986": {
#             "nama": "FARAH FAADHILAH, S.Ag.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LHOKSEUMAWE"
#         }
#     },
#     "9": {
#         "106821": {
#             "nama": "ZULFIKAR H.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LHOKSEUMAWE"
#         },
#         "106822": {
#             "nama": "RAZUARDI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "106823": {
#             "nama": "RINI ANDIYANI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "106824": {
#             "nama": "URIESSAMADIN, S.Hut.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGAH"
#         },
#         "106825": {
#             "nama": "NABILA ARFAH YUANA",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "106826": {
#             "nama": "M. PAISAL AK PUTEH, S.E.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "10": {
#         "107661": {
#             "nama": "Ir. H. ZULNAHAR USMAN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "107662": {
#             "nama": "USMAN ABDULLAH, S.E.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "107663": {
#             "nama": "NOVI YUNITA, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "107664": {
#             "nama": "KHALID SAPUTRA, S.Kom.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BIREUEN"
#         },
#         "107665": {
#             "nama": "CUT MEUTIA, S.H., M.H.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LHOKSEUMAWE"
#         },
#         "107666": {
#             "nama": "NAZAR",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "11": {
#         "108501": {
#             "nama": "MAULUDDIN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "108502": {
#             "nama": "ZIMI ARAMIKO",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BENER MERIAH"
#         },
#         "108503": {
#             "nama": "TAMY FATMILA IBRAHIM, S.Sos.I.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "108504": {
#             "nama": "MUSTAFA ABDULLAH, S.E.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "108505": {
#             "nama": "ARI YOGA",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "PANDEGLANG"
#         },
#         "108506": {
#             "nama": "KARYAWATI",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "PANDEGLANG"
#         }
#     },
#     "12": {
#         "109341": {
#             "nama": "Ir. H. MAWARDI ALI",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "109342": {
#             "nama": "Dr. H. S MALTHA, S.I.K., S.H., M.Si.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "109343": {
#             "nama": "Ir. MEUTIA SAFRIDA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "109344": {
#             "nama": "H. AMINULLAH USMAN, S.E.Ak., M.M.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "109345": {
#             "nama": "NONONG SAKURA",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA TANGERANG SELATAN"
#         },
#         "109346": {
#             "nama": "TEUKU HASBULLAH H.D., S.T.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "13": {
#         "110181": {
#             "nama": "RUSLI, S.Sos.I.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110182": {
#             "nama": "MAWARDI, S.Pd.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110183": {
#             "nama": "Rita Septiana, A.Md.Keb.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110184": {
#             "nama": "T. MAHYUDDIN A.R.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "110185": {
#             "nama": "MUZAKKIR",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BIREUEN"
#         },
#         "110186": {
#             "nama": "Rosda Lyanti",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH SELATAN"
#         }
#     },
#     "14": {
#         "111021": {
#             "nama": "MUSLIM, S.H.I., M.M.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "111022": {
#             "nama": "RIDHWAN ARIFFALAH RUSLI BINTANG, B.Sc., M.A.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA UTARA"
#         },
#         "111023": {
#             "nama": "CUT YANTI NORA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH UTARA"
#         },
#         "111024": {
#             "nama": "HERIYANSYAH",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TIMUR"
#         },
#         "111025": {
#             "nama": "HAMZAH TUN, S.H.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TENGAH"
#         },
#         "111026": {
#             "nama": "ADE REZA MEUTIA, S.Tr.Keb.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         }
#     },
#     "15": {
#         "111861": {
#             "nama": "MUHAMMAD ZUBIR, S.H., M.H.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "111862": {
#             "nama": "HERIZAL",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         },
#         "111863": {
#             "nama": "YUNINGSIH, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         },
#         "111864": {
#             "nama": "HAMDANI",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH TAMIANG"
#         },
#         "111865": {
#             "nama": "RIRIN RAHMADHANI, S.T.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "111866": {
#             "nama": "ZULKHAIRI",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         }
#     },
#     "16": {
#         "112701": {
#             "nama": "HUSAINI M. AMIN, S.E.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "112702": {
#             "nama": "ANDI SYAFRIZAL, S.KH.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "112703": {
#             "nama": "CUT DINDA APRILIANI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA UTARA"
#         },
#         "112704": {
#             "nama": "dr. ICHSAN",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BIREUEN"
#         },
#         "112705": {
#             "nama": "NOERFAIZI, S.H.",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA LANGSA"
#         },
#         "112706": {
#             "nama": "FIEN HERAWATI",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA TANGERANG SELATAN"
#         }
#     },
#     "17": {
#         "113541": {
#             "nama": "Drs. H. ANWAR IDRIS",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "113542": {
#             "nama": "Dr. H. TARMIZI A. KARIM",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "113543": {
#             "nama": "CUT SITI MAISYARAH",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "ACEH UTARA"
#         },
#         "113544": {
#             "nama": "MUNAWAR KHALIL",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH UTARA"
#         },
#         "113545": {
#             "nama": "NYA'ZATA AMANI",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA BANDA ACEH"
#         },
#         "113546": {
#             "nama": "SIKDAM",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA DEPOK"
#         }
#     },
#     "24": {
#         "114381": {
#             "nama": "Drs. SAID DJAMALUL ABIDIN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BEKASI"
#         },
#         "114382": {
#             "nama": "M. ARIS, S.Pd.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "114383": {
#             "nama": "YUSNILAWATI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LHOKSEUMAWE"
#         },
#         "114384": {
#             "nama": "MUHAMMAD YUSUF, S.E.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH UTARA"
#         },
#         "114385": {
#             "nama": "CUT YUMA ASMAHATI",
#             "nomor_urut": 5,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA LHOKSEUMAWE"
#         },
#         "114386": {
#             "nama": "Drs. SAID SADIKIN, M.M.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "ACEH BESAR"
#         }
#     }
# }
# {
#     "1": {
#         "100131": {
#             "nama": "ASHARI TAMBUNAN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "DELI SERDANG"
#         },
#         "100132": {
#             "nama": "SURYANI PASKAH, S.Sos.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "100133": {
#             "nama": "SYAHRIANTO, S.H.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "SERDANG BEDAGAI"
#         },
#         "100134": {
#             "nama": "RANIA ADIBA DASOPANG",
#             "nomor_urut": 4,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "100135": {
#             "nama": "MIKHAEL BENYAMIN SINAGA",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA UTARA"
#         },
#         "100136": {
#             "nama": "BURHANUDDIN",
#             "nomor_urut": 6,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "100137": {
#             "nama": "MULYADI HARTONO",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "DELI SERDANG"
#         },
#         "100138": {
#             "nama": "ROBAH MAHZUNI, S.I.Kom.",
#             "nomor_urut": 8,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "100139": {
#             "nama": "IVANA",
#             "nomor_urut": 9,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA BARAT"
#         },
#         "100140": {
#             "nama": "TOMMY TANTAWI TAN",
#             "nomor_urut": 10,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MEDAN"
#         }
#     },
#     "2": {
#         "100971": {
#             "nama": "ROMO H. R. MUHAMMAD SYAFII, S.H., M.Hum.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "100972": {
#             "nama": "ADE JONA PRASETYO",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "100973": {
#             "nama": "NONA GAYATRI NASUTION",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA TANGERANG SELATAN"
#         },
#         "100974": {
#             "nama": "M. HUSNI, S.E., M.M.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "100975": {
#             "nama": "MARTIN H. HUTABARAT",
#             "nomor_urut": 5,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "100976": {
#             "nama": "AGUS SULISTYANINGSIH, S.Sos., M.A.P.",
#             "nomor_urut": 6,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "100977": {
#             "nama": "RUSLIM ROHIMUN SEMBIRING, S.E.",
#             "nomor_urut": 7,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "100978": {
#             "nama": "V. CONGGO MELIALA, S.E.",
#             "nomor_urut": 8,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "100979": {
#             "nama": "SARAH SABIRA",
#             "nomor_urut": 9,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA BARAT"
#         },
#         "100980": {
#             "nama": "ALIM NUR NASUTION",
#             "nomor_urut": 10,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MEDAN"
#         }
#     },
#     "3": {
#         "101811": {
#             "nama": "Prof. Dr. YASONNA H. LAOLY, S.H., M.Sc.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "101812": {
#             "nama": "Dr. SOFYAN TAN",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MEDAN"
#         },
#         "101813": {
#             "nama": "SRI MULYANI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KARANGANYAR"
#         },
#         "101814": {
#             "nama": "RUHUT POLTAK SITOMPUL, S.H.",
#             "nomor_urut": 4,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "101815": {
# ...
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "JAYAPURA"
#         },
#         "106743": {
#             "nama": "ERNI OKTORIANI M. RUMBEKWAN, S.Pd.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BIAK NUMFOR"
#         }
#     },
#     "9": {
#         "107581": {
#             "nama": "FRANGKY MIRINO",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "107582": {
#             "nama": "SHATYANA FAJAR SARI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "107583": {
#             "nama": "YUSAK S. WONATOREY",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA BARAT"
#         }
#     },
#     "10": {
#         "108421": {
#             "nama": "Dr. KENIUS KOGOYA, S.P., M.Si.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "108422": {
#             "nama": "JOHANNES MARKUS KABEY",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "108423": {
#             "nama": "RIYANTI PUSPITA SURIANI BONAI, S.S.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "BOGOR"
#         }
#     },
#     "11": {
#         "109261": {
#             "nama": "WILLY KURNIAWAN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "NABIRE"
#         },
#         "109262": {
#             "nama": "DEPI RAMADHANI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "109263": {
#             "nama": "ALI SUHADA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "SERANG"
#         }
#     },
#     "12": {
#         "110101": {
#             "nama": "LUCKY RUDINI FONATABA, S.T. M.Sc.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "JAYAPURA"
#         },
#         "110102": {
#             "nama": "GASPER IFAN IMBIRI, S.E.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "WAROPEN"
#         },
#         "110103": {
#             "nama": "SUKMAWATI SULTHAN, S.K.M.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         }
#     },
#     "13": {
#         "110941": {
#             "nama": "HONAILEKMA ASSO",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "JAYAWIJAYA"
#         },
#         "110942": {
#             "nama": "MARTHA GIAY, S.Kom.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "JAYAPURA"
#         },
#         "110943": {
#             "nama": "ALFRIDA YEIMO",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         }
#     },
#     "14": {
#         "111781": {
#             "nama": "YULCE WENDA, S.H.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "111782": {
#             "nama": "APEDIUS I. MOTE, S.T.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "111783": {
#             "nama": "MELKIANUS LAVIANO DOOM, A.Md.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         }
#     },
#     "15": {
#         "112621": {
#             "nama": "COSTANTIEN ANSANAY, S.H.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "112622": {
#             "nama": "MERIAN TODING, S.E.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "JAYAPURA"
#         },
#         "112623": {
#             "nama": "DANOER DORO WIDYAWAN",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA YOGYAKARTA"
#         }
#     },
#     "16": {
#         "113461": {
#             "nama": "Pdt. Dr. EDIE RANTE TASAK, M.M.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "113462": {
#             "nama": "FRED FERNANDUS ARONGGEAR",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "113463": {
#             "nama": "INA KURNIA, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         }
#     },
#     "17": {
#         "114301": {
#             "nama": "BADRIKA YELIPELE, S.Pd.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "JAYAPURA"
#         },
#         "114302": {
#             "nama": "MURSANI, S.H., M.H.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "JAYAPURA"
#         },
#         "114303": {
#             "nama": "NURAENI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "GOWA"
#         }
#     },
#     "24": {
#         "115141": {
#             "nama": "Dr. FRANS KAFIAR",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "JAYAPURA"
#         },
#         "115142": {
#             "nama": "ANASTHASIA HUNAMFAY",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA JAYAPURA"
#         },
#         "115143": {
#             "nama": "DEDI SETIAWAN",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KEEROM"
#         }
#     }
# }
# {
#     "1": {
#         "100871": {
#             "nama": "SIUS DOWANSIBA",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "100872": {
#             "nama": "ANGGRAENI, S.K.M.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA SORONG"
#         },
#         "100873": {
#             "nama": "GANI BULO, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA BEKASI"
#         }
#     },
#     "2": {
#         "101711": {
#             "nama": "MOHAMAD LAKOTANI",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "101712": {
#             "nama": "ETHA BULO, S.H.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA PUSAT"
#         },
#         "101713": {
#             "nama": "JULYMEN A.S. MUMU",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "3": {
#         "102551": {
#             "nama": "OBET RUMBRUREN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "102552": {
#             "nama": "Drs. MATIAS MAIRUMA, M.M.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KAIMANA"
#         },
#         "102553": {
#             "nama": "IDA NOVELINA, S.E.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "4": {
#         "103391": {
#             "nama": "ROMA MEGAWANTY P, S.Kom., M.Si.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "103392": {
#             "nama": "drg. ALFONS MANIBUI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "TELUK BINTUNI"
#         },
#         "103393": {
#             "nama": "Dr. Drs. MOHAMMAD USWANAS, M.Si.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "FAK FAK"
#         }
#     },
#     "5": {
#         "104231": {
#             "nama": "CHEROLINE CHRISYE MAKALEW",
#             "nomor_urut": 1,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "104232": {
#             "nama": "SAUL RANTE LEMBANG, S.T., M.M.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "104233": {
#             "nama": "Dr. MERVIN SADIPUN KOMBER, S.T., S.E., M.M.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "FAK FAK"
#         }
#     },
#     "6": {
#         "105071": {
#             "nama": "NURYASIN, S.H.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BEKASI"
#         },
#         "105072": {
#             "nama": "NUR SALDI RUMBOUW",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "FAK FAK"
#         },
#         "105073": {
#             "nama": "NUR ABIDIN ALKAAFI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "BEKASI"
#         }
#     },
#     "7": {
#         "105911": {
#             "nama": "CHARLOS CHRISTOFOR MARYEN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "105912": {
#             "nama": "PUTRI RAHMADANI RASYID",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "105913": {
#             "nama": "YAN ARWAM",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "8": {
#         "106751": {
#             "nama": "H. MUGIYONO, S.Hut.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "106752": {
#             "nama": "ABDUL KARIM ANGGILULI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MIMIKA"
#         },
#         "106753": {
#             "nama": "NOOR AENI, S.P.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "9": {
#         "107591": {
#             "nama": "YOHANES ORUN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "107592": {
#             "nama": "ML. TUMINAH",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "10": {
#         "108431": {
#             "nama": "LEVINUS WANGGAI, S.I.P.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "108432": {
#             "nama": "INDORANY YESENIA YULFANDA TATIORIM",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "108433": {
#             "nama": "ISMET INUNI MAU, S.H., M.H., M.M.Pd.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "11": {
#         "109271": {
#             "nama": "MAX HANS LEFAAN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA SORONG"
#         },
#         "109272": {
#             "nama": "BRIAN MARCELIUS RUMY",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KAIMANA"
#         },
#         "109273": {
#             "nama": "SARTIKA SARI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA CILEGON"
#         }
#     },
#     "12": {
#         "110111": {
#             "nama": "dr. ROSALINE IRENE RUMASEUW, M.Kes.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "110112": {
#             "nama": "GREEZ NATALIA",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA SELATAN"
#         },
#         "110113": {
#             "nama": "MUHAMMAD REZA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "13": {
#         "110951": {
#             "nama": "ARIS MARYANI",
#             "nomor_urut": 1,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA TANGERANG SELATAN"
#         },
#         "110952": {
#             "nama": "HIDAYATULLAH NASRI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "HALMAHERA TENGAH"
#         },
#         "110953": {
#             "nama": "HAMDANI ABD. RAHIM",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "HALMAHERA TENGAH"
#         }
#     },
#     "14": {
#         "111791": {
#             "nama": "ARIFIN, S.E.",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KAIMANA"
#         },
#         "111792": {
#             "nama": "SUNTRYSKA R.V. PURBA, S.H.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KEEROM"
#         },
#         "111793": {
#             "nama": "ROBERTH R.A. RUMBEKWAN, S.H., M.H.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         }
#     },
#     "15": {
#         "112631": {
#             "nama": "WAWAN SETIAWAN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA MAKASSAR"
#         },
#         "112632": {
#             "nama": "MARIA TRIANAWATI A.W.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA SURAKARTA"
#         },
#         "112633": {
#             "nama": "DEWI BUDIYANTI",
#             "nomor_urut": 3,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA SURAKARTA"
#         }
#     },
#     "16": {
#         "113471": {
#             "nama": "Drs. SOLEMAN SIKIRIT",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "113472": {
#             "nama": "SOFYA ELY",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "KOTA ADM. JAKARTA BARAT"
#         },
#         "113473": {
#             "nama": "DIMAS HADITYO KURNIA PUTRA",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         }
#     },
#     "17": {
#         "114311": {
#             "nama": "TAMIRUDDIN",
#             "nomor_urut": 1,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "TELUK BINTUNI"
#         },
#         "114312": {
#             "nama": "SURIANI",
#             "nomor_urut": 2,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "GOWA"
#         },
#         "114313": {
#             "nama": "FAJAR KUKUH SIGIT CAHYONO, S.Hut.",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "TELUK BINTUNI"
#         }
#     },
#     "24": {
#         "115151": {
#             "nama": "JUNITA DOMA THERESSA MAMBOR",
#             "nomor_urut": 1,
#             "jenis_kelamin": "P",
#             "tempat_tinggal": "MANOKWARI"
#         },
#         "115152": {
#             "nama": "ARIF BUDIMAN, S.H., S.Sos., M.Si.",
#             "nomor_urut": 2,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA DEPOK"
#         },
#         "115153": {
#             "nama": "Dr. SUHARDI SOMOMOELJONO",
#             "nomor_urut": 3,
#             "jenis_kelamin": "L",
#             "tempat_tinggal": "KOTA ADM. JAKARTA TIMUR"
#         }
#     }
# }

# %% [markdown]
# # *PROFIL DPR COMPLETE*

# %% [markdown]
# > ### *Preparation*

# %%
driver = webdriver.Chrome()
url = 'https://infopemilu.kpu.go.id/Pemilu/Dct_dpr'
driver.get(url)

# %% [markdown]
# > ### *Frameowork 1: Region Looping*

# %%
# NOTE #
# Any change after framework 1 & 2 are finished is done in framework 3

# %%
# COMMAND HERE (works per 15/08/2024) #

DPR = pd.DataFrame() # for the DataFrame

for i in range(1, 85):
    driver.refresh();
    time.sleep(1)
    driver.find_element(By.XPATH, '//*[@id="register"]/div/span/span[1]/span').click()
    region = driver.find_elements(By.CSS_SELECTOR, 'li.select2-results__option')
    try:
        region[i].click()
    except IndexError as wait_region:
        driver.refresh();
        time.sleep(2)
        region[i].click()
    wait = WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="tbl_ms_nasional"]/tbody/tr[1]/td[9]/form/input[7]')))

    # loading profiles in each region
    profile = driver.find_elements(By.CSS_SELECTOR, 'tr.odd, tr.even')
    for x in profile:
        try:
            ###### Profile Scraping ######
        except NoSuchElementException as private_profile: 
            continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#      14 x.find_element(By.CLASS_NAME, 'btn-secondary').click()
#      15 ##### INSERT PROFILE SCRAPING BELOW ######
# ---> 16 time.sleep(1)
#      17 ##### INSERT PROFILE SCRAPING ABOVE ######
#      18 driver.back();
#
# KeyboardInterrupt:

# %% [markdown]
# **To review**
# <br/>
# Scrolldown is necessary and not yet implemented
# <br/><br/>
# *Some Example*
# <br/>
# driver.execute_script("arguments[0].scrollIntoView();", x.find_element(By.CLASS_NAME, 'btn-secondary'))

# %% [markdown]
# > ### *Framework 2: Profile Scraping*

# %%
# REFERENCE #

# NAME
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[1]/td[2]

# BIRTHPLACE
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[2]/td[2]

# BIRTHDATE
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[3]/td[2]

# AGE
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[4]/td[2]

# GENDER
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[5]/td[2]

# RELIGION
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[6]/td[2]

# MARITAL
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[7]/td[2]

# DISABILITY
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table/tbody/tr[8]/td[2]

# FULL ADDRESS (FORMAT IS LIKE ADDRESS)
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/li[1]/text()
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/li[2]/text()
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/li[3]/text()
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/li[7]/text()
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/li[6]/text()
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/li[5]/text()
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/li[4]/text()

# CURRENT JOB
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[3]/p

# PREVIOUS JOBS (JABATAN + PERUSAHAAN, MASUK + KELUAR)
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table/tbody/tr[1]/td[2]
## /html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table/tbody/tr[1]/td[1]
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table/tbody/tr[1]/td[3]
## /html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table/tbody/tr[1]/td[4]

# LEGAL STATUS
# /html/body/div[2]/div[3]/div/div/div[1]/div/div[5]/p

# PENDIDIKAN (JENJANG + TEMPAT + TAHUN MASUK + TAHUN KELUAR)
##
##
##
##

# %%
# NOTE #
# Any change after framework 1 & 2 are finished is done in framework 3

# %%
# COMMAND HERE #

################################################################ Non-Table ##################################################################
dpr = []

# General Identity
identity_2 = driver.find_element(By.XPATH, "/html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table")
identity_1 = identity_2.find_elements(By.XPATH, ".//tr")
for x in identity_1:
    identity = x.find_element(By.XPATH, ".//td")
    general_identity = x.text
    dpr.append(general_identity)
    
# Address
address_2 = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[2]')
address_1 = address_2.find_elements(By.XPATH, ".//li")
for x in address_1:
    general_address = x.text
    dpr.append(general_address)

# Job
job = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[3]/p')
jobs = job.text
dpr.append({'Pekerjaan':jobs})

# Legal Status
legalstatus = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[5]/p')
legal = legalstatus.text
dpr.append({'Status Hukum':legal})

# Program Proposal
progprop = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[11]/li/strong')
proposal = progprop.text
dpr.append({'Program Usulan':proposal})

############## Table ##############
table = []

# Previous Jobs
prev_job = []
prev_job_3 = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table')
prev_job_2 = prev_job_3.find_elements(By.XPATH, ".//tr")[1:]
for x in prev_job_2:
    prev_job_1 = x.text
    prev_job.append(prev_job_1)
    table.append({'Riwayat Pekerjaan':prev_job})

# Previous Educations
prev_educ = []
prev_educ_3 = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[6]/table')
prev_educ_2 = prev_educ_3.find_elements(By.XPATH, ".//tr")[1:]
for x in prev_educ_2:
    prev_educ_1 = x.text
    prev_educ.append(prev_educ_1)
    table.append({'Riwayat Edukasi':prev_educ})

# Previous course
prev_course = []
prev_course_3 = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[7]/table')
prev_course_2 = prev_course_3.find_elements(By.XPATH, ".//tr")[1:]
for x in prev_course_2:
    prev_course_1 = x.text
    prev_course.append(prev_course_1)
    table.append({'Riwayat Kursus & Diklat':prev_course})

# Previous Organization
prev_org = []
prev_org_3 = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[8]/table')
prev_org_2 = prev_org_3.find_elements(By.XPATH, ".//tr")[1:]
for x in prev_org_2:
    prev_org_1 = x.text
    prev_org.append(prev_org_1)
    table.append({'Riwayat Organisasi':prev_org})

# Previous Awards
prev_awards = []
prev_awards_3 = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[9]/table')
prev_awards_2 = prev_awards_3.find_elements(By.XPATH, ".//tr")[1:]
for x in prev_awards_2:
    prev_awards_1 = x.text
    prev_awards.append(prev_awards_1)
    table.append({'Riwayat Penghargaan':prev_awards})
    
dpr_table = {}
for x in table:
    dpr_table.update(x)

############## DataFrame ##############
dpr_list = {x.split(': ')[0]: x.split(': ')[1] for x in dpr if ': ' in x}
DPR_column = pd.DataFrame([dpr_list])
DPR_table = pd.DataFrame([dpr_table])
DPR_full = pd.concat([DPR_column, DPR_table], axis=1)
DPR = pd.concat([DPR, DPR_full], ignore_index=True)
driver.back();

DPR
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[156], line 26
#      23 dpr.append({'Pekerjaan':jobs})
#      25 # Legal Status
# ---> 26 legalstatus = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div/div[1]/div/div[5]/p')
#      27 legal = legalstatus.text
#      28 dpr.append({'Status Hukum':legal})
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div[3]/div/div/div[1]/div/div[5]/p"}
#   (Session info: chrome=127.0.6533.101); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7E1A79642+30946]
# 	(No symbol) [0x00007FF7E1A2E3D9]
# 	(No symbol) [0x00007FF7E1926FDA]
# 	(No symbol) [0x00007FF7E197822C]
# 	(No symbol) [0x00007FF7E197850C]
# 	(No symbol) [0x00007FF7E19BDCB7]
# 	(No symbol) [0x00007FF7E199CAAF]
# 	(No symbol) [0x00007FF7E19BB041]
# 	(No symbol) [0x00007FF7E199C813]
# 	(No symbol) [0x00007FF7E196A6E5]
# 	(No symbol) [0x00007FF7E196B021]
# 	GetHandleVerifier [0x00007FF7E1BAF84D+1301229]
# 	GetHandleVerifier [0x00007FF7E1BBBDC7+1351783]
# 	GetHandleVerifier [0x00007FF7E1BB2A13+1313971]
# 	GetHandleVerifier [0x00007FF7E1AADD16+245686]
# 	(No symbol) [0x00007FF7E1A3759F]
# 	(No symbol) [0x00007FF7E1A33814]
# 	(No symbol) [0x00007FF7E1A339A2]
# 	(No symbol) [0x00007FF7E1A2A3FF]
# 	BaseThreadInitThunk [0x00007FFCAF95257D+29]
# 	RtlUserThreadStart [0x00007FFCB066AF28+40]

# %%
# CHATGPT MODIFIED #   
# Modified for handling data that is missing. In the original, it would skip the whole profile instead

#DPR = pd.DataFrame()

################################################################ Non-Table 
def get_element_text(xpath, blank=""):
    try:
        element = driver.find_element(By.XPATH, xpath)
        return element.text
    except NoSuchElementException as missing_non_table:
        return blank

contact = []

# General Identity
identity_xpath = "/html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table"
identity_rows = get_element_text(identity_xpath).split('\n')
for row in identity_rows:
    contact.append(row)

# Address
address_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[2]'
address_items = get_element_text(address_xpath).split('\n')
for item in address_items:
    contact.append(item)

status = []

# Job
job_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[3]/p'
jobs = get_element_text(job_xpath)
status.append(jobs)

# Legal Status
legalstatus_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[5]/p'
legal = get_element_text(legalstatus_xpath)
status.append(legal)

# Program Proposal
progprop_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[11]/li/strong'
proposal = get_element_text(progprop_xpath)
status.append(proposal)

################################################################ Table 
table = []

def get_table_data(xpath, blank=""):
    try:
        table_element = driver.find_element(By.XPATH, xpath)
        rows = table_element.find_elements(By.XPATH, ".//tr")[1:]  
        return [row.text for row in rows]
    except NoSuchElementException as missing_table:
        return blank

# Previous Jobs
prev_job_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table')
table.append({'Riwayat Pekerjaan': prev_job_data})

# Previous Educations
prev_educ_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[6]/table')
table.append({'Riwayat Edukasi': prev_educ_data})

# Previous Courses
prev_course_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[7]/table')
table.append({'Riwayat Kursus & Diklat': prev_course_data})

# Previous Organizations
prev_org_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[8]/table')
table.append({'Riwayat Organisasi': prev_org_data})

# Previous Awards
prev_awards_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[9]/table')
table.append({'Riwayat Penghargaan': prev_awards_data})

# Combine tables into a single dictionary
dpr_table = {}
for entry in table:
    dpr_table.update(entry)

################################################################ DataFrame 
# Contact
contact_list = {x.split(': ')[0]: x.split(': ')[1] for x in contact if ': ' in x}
DPR_contact = pd.DataFrame([contact_list])

# Status
DPR_status = pd.DataFrame(columns=['Pekerjaan', 'Status Hukum', 'Program Usulan'])
length = len(DPR_status)
DPR_status.loc[length] = status

# Contact+Status
DPR_contus = pd.concat([DPR_contact, DPR_status], axis=1)

# Table
DPR_table = pd.DataFrame([dpr_table])

# Complete (Contact+Status+Table)
DPR_full = pd.concat([DPR_contus, DPR_table], axis=1)

# Appending the loops
DPR = pd.concat([DPR, DPR_full], ignore_index=True)
# Out:
#                Nama Lengkap   Tempat Lahir Tanggal Lahir      Usia  \
# 0  H. IRMAWAN, S.Sos., M.M.  aceh tenggara    21-12-1967  55 tahun
# 1  H. IRMAWAN, S.Sos., M.M.  aceh tenggara    21-12-1967  55 tahun
# 2  H. IRMAWAN, S.Sos., M.M.  aceh tenggara    21-12-1967  55 tahun
#
#   Jenis Kelamin  Agama Status Perkawinan            Status Disabilitas  \
# 0     LAKI-LAKI  Islam             Sudah  Bukan Penyandang Disabilitas
# 1     LAKI-LAKI  Islam             Sudah  Bukan Penyandang Disabilitas
# 2     LAKI-LAKI  Islam             Sudah  Bukan Penyandang Disabilitas
#
#                                       Alamat lengkap  RT   ...    Kecamatan  \
# 0  komplek perumahan villa asri lamglumpang ulee ...  000  ...  ULEE KARENG
# 1  komplek perumahan villa asri lamglumpang ulee ...  000  ...  ULEE KARENG
# 2  komplek perumahan villa asri lamglumpang ulee ...  000  ...  ULEE KARENG
#
#      Kelurahan    Pekerjaan                 Status Hukum  \
# 0  LAMGLUMPANG  ANGGOTA DPR  Tidak Memiliki Status Hukum
# 1  LAMGLUMPANG  ANGGOTA DPR  Tidak Memiliki Status Hukum
# 2  LAMGLUMPANG  ANGGOTA DPR  Tidak Memiliki Status Hukum
#
#                                       Program Usulan  \
# 0  Memperjuangkan APBN supaya lebih menyentuh kep...
# 1  Memperjuangkan APBN supaya lebih menyentuh kep...
# 2  Memperjuangkan APBN supaya lebih menyentuh kep...
#
#                                    Riwayat Pekerjaan  \
# 0  [DPR-RI ANGGOTA 2014 2019, DPR-RI ANGGOTA 2019...
# 1  [DPR-RI ANGGOTA 2014 2019, DPR-RI ANGGOTA 2019...
# 2  [DPR-RI ANGGOTA 2014 2019, DPR-RI ANGGOTA 2019...
#
#                                      Riwayat Edukasi Riwayat Kursus & Diklat  \
# 0  [SMA SMA NEGERI 1 BLANGKEJEREN GAYO LUES 1983 ...               [- - - -]
# 1  [SMA SMA NEGERI 1 BLANGKEJEREN GAYO LUES 1983 ...               [- - - -]
# 2  [SMA SMA NEGERI 1 BLANGKEJEREN GAYO LUES 1983 ...               [- - - -]
#
#                                   Riwayat Organisasi Riwayat Penghargaan
# 0  [KNPI GAYO LUES ketua 2004 2007, GAYO MEUSARA ...             [- - -]
# 1  [KNPI GAYO LUES ketua 2004 2007, GAYO MEUSARA ...             [- - -]
# 2  [KNPI GAYO LUES ketua 2004 2007, GAYO MEUSARA ...             [- - -]
#
# [3 rows x 23 columns]

# %%
# FIX 1 UNTESTED #

DPR = pd.DataFrame()

################################################################ Profile Scraping ##################################################################
################################################################ Non-Table 
def get_element_text(xpath, blank=""):
    try:
        element = driver.find_element(By.XPATH, xpath)
        return element.text
    except NoSuchElementException as missing_non_table:
        return blank

contact = []

# General Identity
identity_xpath = "/html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table"
identity_rows = get_element_text(identity_xpath).split('\n')
for row in identity_rows:
    contact.append(row)

# Address
address_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[2]'
address_items = get_element_text(address_xpath).split('\n')
for item in address_items:
    contact.append(item)

status = []

# Job
job_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[3]/p'
jobs = get_element_text(job_xpath)
status.append(jobs)

# Legal Status
legalstatus_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[5]/p'
legal = get_element_text(legalstatus_xpath)
status.append(legal)

# Program Proposal
progprop_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[11]/li/strong'
proposal = get_element_text(progprop_xpath)
status.append(proposal)

################################################################ Table 
table = []

def get_table_data(xpath, blank=""):
    try:
        table_element = driver.find_element(By.XPATH, xpath)
        rows = table_element.find_elements(By.XPATH, ".//tr")[1:]  
        return [row.text for row in rows]
    except NoSuchElementException as missing_table:
        return blank

# Previous Jobs
prev_job_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table')
table.append({'Riwayat Pekerjaan': prev_job_data})

# Previous Educations
prev_educ_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[6]/table')
table.append({'Riwayat Edukasi': prev_educ_data})

# Previous Courses
prev_course_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[7]/table')
table.append({'Riwayat Kursus & Diklat': prev_course_data})

# Previous Organizations
prev_org_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[8]/table')
table.append({'Riwayat Organisasi': prev_org_data})

# Previous Awards
prev_awards_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[9]/table')
table.append({'Riwayat Penghargaan': prev_awards_data})

# Combine tables into a single dictionary
dpr_table = {}
for entry in table:
    dpr_table.update(entry)

################################################################ DataFrame 
# Contact
contact_tobe = [x.split(':')[1] for x in contact if ':' in x]
contact_list = []
for x in contact_tobe:
    if len(x)>0:
        contact_list.append(x[1:])
    else:
        contact_list.append(x)
DPR_contact = pd.DataFrame(columns=['Nama Lengkap', 'Tempat Lahir', 'Tanggal Lahir', 'Usia', 'Jenis Kelamin', 'Agama', 'Status Perkawinan', 'Status Disabilitas', 'Alamat Lengkap', 'RT', 'RW', 'Provinsi', 'Kabupaten/Kota', 'Kecamatan', 'Kelurahan'])
length = len(DPR_contact)
try:
    DPR_contact.loc[length] = contact_list
except ValueError as incomplete_profile:
    DPR_contact = pd.DataFrame(columns=['Nama Lengkap', 'Tempat Lahir', 'Tanggal Lahir', 'Usia', 'Jenis Kelamin', 'Agama', 'Status Perkawinan', 'Status Disabilitas'])
    DPR_contact.loc[length] = contact_list

# Status if profile is incomplete
    DPR_status = pd.DataFrame(columns=['Pekerjaan', 'Status Hukum', 'Program Usulan'])
    length = len(DPR_status)

    status_incomplete = []

    ## Job
    job_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[2]/p'
    jobs = get_element_text(job_xpath)
    status_incomplete.append(jobs)
    
    ## Legal Status
    legalstatus_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[3]/p'
    legal = get_element_text(legalstatus_xpath)
    status_incomplete.append(legal)
    
    ## Program Proposal
    progprop_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[11]/li/strong'
    proposal = get_element_text(progprop_xpath)
    status_incomplete.append(proposal)

    DPR_status.loc[length] = status_incomplete
    
# Status if profile is complete
if len(DPR_contact.columns)>8:
    DPR_status = pd.DataFrame(columns=['Pekerjaan', 'Status Hukum', 'Program Usulan'])
    length = len(DPR_status)
    DPR_status.loc[length] = status

# Contact+Status
DPR_contus = pd.concat([DPR_contact, DPR_status], axis=1)

# Table
DPR_table = pd.DataFrame([dpr_table])

# Complete (Contact+Status+Table)
DPR_full = pd.concat([DPR_contus, DPR_table], axis=1)

# Appending the loops
DPR = pd.concat([DPR, DPR_full], ignore_index=True)
################################################################ Profile Scraping ##################################################################

DPR
# Out:
#                     Nama Lengkap Tempat Lahir Tanggal Lahir      Usia  \
# 0  Dr. TEUKU TAUFIQULHADI, M.Si.         ACEH    17-11-1960  62 tahun
#
#   Jenis Kelamin  Agama Status Perkawinan            Status Disabilitas  \
# 0     Laki-laki  Islam             Sudah  Bukan Penyandang Disabilitas
#
#   Pekerjaan Status Hukum Program Usulan  \
# 0
#
#                                    Riwayat Pekerjaan Riwayat Edukasi  \
# 0  [Kementerian ATR/BPN Staf Khusus 2019 2022, DP...         [- - -]
#
#   Riwayat Kursus & Diklat Riwayat Organisasi Riwayat Penghargaan
# 0

# %%
# FIX 1.A FOR TABLE #

# DPR = pd.DataFrame()

card = driver.find_elements(By.CSS_SELECTOR, 'div.card')
for cards in card:
    non_table = cards.find_elements(By.CSS_SELECTOR, 'div.container:not(.table-responsive)')
    if non_table == []:
        del non_table
        continue
    else:
        break

for cards in card:
    table = cards.find_elements(By.CSS_SELECTOR, 'div.container.table-responsive')
    if table == []:
        del table
        continue
    else:
        break


############################## Non-Table: df_profile

## For all: df_profile
profiles_list = {}
for non in non_table:
    profil = non.find_elements(By.CSS_SELECTOR, 'table.table-striped > tbody > tr > td, li.list-group-item, h3.mt-3') + non.find_elements(By.TAG_NAME, 'p')
    profile = [prof.text.strip() for prof in profil]
    if 'ALAMAT' in profile:
        alamat = {x.split(': ')[0]: x.split(': ')[1] for x in profile if ': ' in x}
    elif 'PROGRAM USULAN' in profile:
        df_programs = pd.DataFrame({profile[0]: [profile[1:]]})
    else:
        for i in range(0, len(profile), 2):
            column_prof = profile[i]
            value_prof = profile[i+1]
            profiles_list[column_prof] = value_prof
        
df_profile_prof = pd.DataFrame([profiles_list])
df_profile_alamat = pd.DataFrame([alamat])
df_profile = pd.concat([df_profile_prof, df_profile_alamat, df_programs], axis=1)

    
############################## Table: df_table

## Table Headers: df_mini_header
dataframes = {}
for i, iden in enumerate(table, start=1):
    mini_header = iden.find_elements(By.CSS_SELECTOR, 'th')
    mini_headers = [mini.text for mini in mini_header]
    df_mini_header = pd.DataFrame(columns = mini_headers) # For each table, create a dataframe. Since some will be empty (for god knows why)....
    
    dataframes[f'df_{i}'] = df_mini_header #... let's try to include only those that are not empty ...
    df_table = [] #... and we fill the non-empty dataframe here
    for j in range(1, len(dataframes) + 1): 
        if dataframes[f'df_{j}'].columns.size > 0:
            df_table.append(dataframes[f'df_{j}'])

## Filling the Columns
iterate = 0 # To note in which dataframe is the iteration in later on
for tab in table:
    value = tab.find_elements(By.CSS_SELECTOR, 'td')
    values = [val.text for val in value]
    if values:  
        # Get the current DataFrame to update
        df = df_table[iterate]
        
        # Split values into chunks based on the number of columns in the DataFrame
        num_columns = len(df.columns)
        
        # If there is literally empty column (not even '-'), fill with empty columns
        if len(values) % num_columns != 0:
            total_values = len(values)
            required_values = (total_values // num_columns + 1) * num_columns # this line is fucking smart. fucking ai man
            values += [''] * (required_values - total_values)

        # Split the rows to fit into the dataframe
        rows = [values[i:i + num_columns] for i in range(0, len(values), num_columns)]
            
        # Create a new DataFrame from the rows and append to the current DataFrame
        df_new = pd.DataFrame(rows, columns=df.columns)
        df_table[iterate] = pd.concat([df, df_new], ignore_index=True)
        
        # Move to the next DataFrame for the next set of values
        iterate += 1
    
    # Break the loop if all DataFrames are populated
    if iterate >= len(df_table):
        break

## Filling the Columns: jobs (inserted to df_table)
for occ in table:
    job_info = occ.find_elements(By.TAG_NAME, 'h3') + occ.find_elements(By.TAG_NAME, 'p')
    jobs_info = [jobs.text.strip() for jobs in job_info]
    jobs = pd.DataFrame({jobs_info[0]:[jobs_info[1]]})
    df_table.append(jobs)
    if len(jobs_info)<=2:
        break

## concatenate the df_table
for i in range(0, len(df_table) - 1):
    if len(df_table[i])>1:
        df_table[i] = pd.DataFrame({col: [', '.join(df_table[i][col])] for col in df_table[i].columns})
    else:
        continue

df_table = pd.concat(df_table, axis=1) 

############################## Final
DPR_profile = pd.concat([df_profile, df_table], axis=1)
try:
    DPR = pd.concat([DPR, DPR_profile], ignore_index=True)
except InvalidIndexError as formatting:
    DPR = pd.concat([DPR, DPR_profile], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[496], line 113
#     112 try:
# --> 113     DPR = pd.concat([DPR, DPR_profile], ignore_index=True)
#     114 except InvalidIndexError as formatting:
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\reshape\concat.py:676, in _Concatenator.get_result(self)
#     675     if not new_labels.equals(obj_labels):
# --> 676         indexers[ax] = obj_labels.get_indexer(new_labels)
#     678 mgrs_indexers.append((obj._mgr, indexers))
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\indexes\base.py:3875, in Index.get_indexer(self, target, method, limit, tolerance)
#    3874 if not self._index_as_unique:
# -> 3875     raise InvalidIndexError(self._requires_unique_msg)
#    3877 if len(target) == 0:
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[496], line 115
#     113     DPR = pd.concat([DPR, DPR_profile], ignore_index=True)
#     114 except InvalidIndexError as formatting:
# --> 115     DPR = pd.concat([DPR, DPR_profile], ignore_index=True)
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\reshape\concat.py:676, in _Concatenator.get_result(self)
#     674         obj_labels = obj.axes[1 - ax]
#     675         if not new_labels.equals(obj_labels):
# --> 676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
#     680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\indexes\base.py:3875, in Index.get_indexer(self, target, method, limit, tolerance)
#    3872 self._check_indexing_method(method, limit, tolerance)
#    3874 if not self._index_as_unique:
# -> 3875     raise InvalidIndexError(self._requires_unique_msg)
#    3877 if len(target) == 0:
#    3878     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %% [markdown]
# > ### *Framework 3: COMPLETE CODE*

# %%
# COMMAND HERE (works per 15/08/2024) #

DPR = pd.DataFrame() 

for i in range(1, 85):
    driver.refresh();
    time.sleep(1)
    driver.find_element(By.XPATH, '//*[@id="register"]/div/span/span[1]/span').click()
    region = driver.find_elements(By.CSS_SELECTOR, 'li.select2-results__option')
    try:
        region[i].click()
    except IndexError as wait_region:
        driver.refresh();
        time.sleep(2)
        region[i].click()
    wait = WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="tbl_ms_nasional"]/tbody/tr[1]/td[9]/form/input[7]')))

    # loading profiles in each region
    profile = driver.find_elements(By.CSS_SELECTOR, 'tr.odd, tr.even')
    for x in profile:
        try:
            wait = WebDriverWait(driver, 20).until(EC.presence_of_element_located((By.XPATH, '//*[@id="tbl_ms_nasional"]/tbody')))
            try:
                x.find_element(By.CLASS_NAME, 'btn-secondary').click()
            except StaleElementReferenceException as wait_back:
                time.sleep(1)
                driver.back();
                x.find_element(By.CLASS_NAME, 'btn-secondary').click()
            except ElementClickInterceptedException as scroll:
                driver.execute_script("window.scrollBy(0, 500);")
                time.sleep(1)
                x.find_element(By.CLASS_NAME, 'btn-secondary').click()
                
            ################################################################ Profile Scraping ##################################################################
            ################################################################ Non-Table 
            def get_element_text(xpath, blank=""):
                try:
                    element = driver.find_element(By.XPATH, xpath)
                    return element.text
                except NoSuchElementException as missing_non_table:
                    return blank
            
            contact = []
            
            # General Identity
            identity_xpath = "/html/body/div[2]/div[3]/div/div/div[1]/div/div[1]/div/div[4]/table"
            identity_rows = get_element_text(identity_xpath).split('\n')
            for row in identity_rows:
                contact.append(row)
            
            # Address
            address_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[2]'
            address_items = get_element_text(address_xpath).split('\n')
            for item in address_items:
                contact.append(item)
            
            status = []
            
            # Job
            job_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[3]/p'
            jobs = get_element_text(job_xpath)
            status.append(jobs)
            
            # Legal Status
            legalstatus_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[5]/p'
            legal = get_element_text(legalstatus_xpath)
            status.append(legal)
            
            # Program Proposal
            progprop_xpath = '/html/body/div[2]/div[3]/div/div/div[1]/div/div[11]/li/strong'
            proposal = get_element_text(progprop_xpath)
            status.append(proposal)
            
            ################################################################ Table 
            table = []
            
            def get_table_data(xpath, blank=""):
                try:
                    table_element = driver.find_element(By.XPATH, xpath)
                    rows = table_element.find_elements(By.XPATH, ".//tr")[1:]  
                    return [row.text for row in rows]
                except NoSuchElementException as missing_table:
                    return blank
            
            # Previous Jobs
            prev_job_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[4]/table')
            table.append({'Riwayat Pekerjaan': prev_job_data})
            
            # Previous Educations
            prev_educ_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[6]/table')
            table.append({'Riwayat Edukasi': prev_educ_data})
            
            # Previous Courses
            prev_course_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[7]/table')
            table.append({'Riwayat Kursus & Diklat': prev_course_data})
            
            # Previous Organizations
            prev_org_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[8]/table')
            table.append({'Riwayat Organisasi': prev_org_data})
            
            # Previous Awards
            prev_awards_data = get_table_data('/html/body/div[2]/div[3]/div/div/div[1]/div/div[9]/table')
            table.append({'Riwayat Penghargaan': prev_awards_data})
            
            # Combine tables into a single dictionary
            dpr_table = {}
            for entry in table:
                dpr_table.update(entry)
            
            ################################################################ DataFrame 
            # Contact
            contact_list = {x.split(': ')[0]: x.split(': ')[1] for x in contact if ': ' in x}
            DPR_contact = pd.DataFrame([contact_list])
            
            # Status
            DPR_status = pd.DataFrame(columns=['Pekerjaan', 'Status Hukum', 'Program Usulan'])
            length = len(DPR_status)
            DPR_status.loc[length] = status
            
            # Contact+Status
            DPR_contus = pd.concat([DPR_contact, DPR_status], axis=1)
            
            # Table
            DPR_table = pd.DataFrame([dpr_table])
            
            # Complete (Contact+Status+Table)
            DPR_full = pd.concat([DPR_contus, DPR_table], axis=1)
            
            # Appending the loops
            DPR = pd.concat([DPR, DPR_full], ignore_index=True)
            ################################################################ Profile Scraping ##################################################################
            
            # Back
            driver.back(); 
        except NoSuchElementException as private_profile: 
            continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[109], line 16
#      14     time.sleep(2)
#      15     region[i].click()
# ---> 16 wait = WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="tbl_ms_nasional"]/tbody/tr[1]/td[9]/form/input[7]')))
#      18 # loading profiles in each region
#      19 profile = driver.find_elements(By.CSS_SELECTOR, 'tr.odd, tr.even')
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\selenium\webdriver\support\wait.py:102, in WebDriverWait.until(self, method, message)
#     100     screen = getattr(exc, "screen", None)
#     101     stacktrace = getattr(exc, "stacktrace", None)
# --> 102 time.sleep(self._poll)
#     103 if time.monotonic() > end_time:
#     104     break
#
# KeyboardInterrupt:

# %%
# FIX 1 UNTESTED (using 1.A scraping) #

DPR = pd.DataFrame() 

for i in range(1, 85):
    driver.refresh();
    time.sleep(1)
    driver.find_element(By.XPATH, '//*[@id="register"]/div/span/span[1]/span').click()
    region = driver.find_elements(By.CSS_SELECTOR, 'li.select2-results__option')
    try:
        region[i].click()
    except IndexError as wait_region:
        driver.refresh();
        time.sleep(2)
        region[i].click()
    wait = WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="tbl_ms_nasional"]/tbody/tr[1]/td[9]/form/input[7]')))

    # loading profiles in each region
    profile = driver.find_elements(By.CSS_SELECTOR, 'tr.odd, tr.even')
    for x in profile:
        try:
            wait = WebDriverWait(driver, 20).until(EC.presence_of_element_located((By.XPATH, '//*[@id="tbl_ms_nasional"]/tbody')))
            try:
                x.find_element(By.CLASS_NAME, 'btn-secondary').click()
            except StaleElementReferenceException as wait_back:
                time.sleep(1)
                driver.back();
                x.find_element(By.CLASS_NAME, 'btn-secondary').click()
            except ElementClickInterceptedException as scroll:
                driver.execute_script("window.scrollBy(0, 500);")
                time.sleep(1)
                x.find_element(By.CLASS_NAME, 'btn-secondary').click()
                
            ################################################################ Profile Scraping ##################################################################
            card = driver.find_elements(By.CSS_SELECTOR, 'div.card')
            for cards in card:
                non_table = cards.find_elements(By.CSS_SELECTOR, 'div.container:not(.table-responsive)')
                if non_table == []:
                    del non_table
                    continue
                else:
                    break
            
            for cards in card:
                table = cards.find_elements(By.CSS_SELECTOR, 'div.container.table-responsive')
                if table == []:
                    del table
                    continue
                else:
                    break
            
            
            ############################## Non-Table: df_profile
            
            ## For all: df_profile
            profiles_list = {}
            for non in non_table:
                profil = non.find_elements(By.CSS_SELECTOR, 'table.table-striped > tbody > tr > td, li.list-group-item, h3.mt-3') + non.find_elements(By.TAG_NAME, 'p')
                profile = [prof.text.strip() for prof in profil]
                if 'ALAMAT' in profile:
                    alamat = {x.split(': ')[0]: x.split(': ')[1] for x in profile if ': ' in x}
                elif 'PROGRAM USULAN' in profile:
                    df_programs = pd.DataFrame({profile[0]: [profile[1:]]})
                else:
                    for i in range(0, len(profile), 2):
                        column_prof = profile[i]
                        value_prof = profile[i+1]
                        profiles_list[column_prof] = value_prof
                    
            df_profile_prof = pd.DataFrame([profiles_list])
            df_profile_alamat = pd.DataFrame([alamat])
            df_profile = pd.concat([df_profile_prof, df_profile_alamat, df_programs], axis=1)
            
                
            ############################## Table: df_table
            
            ## Table Headers: df_mini_header
            dataframes = {}
            for i, iden in enumerate(table, start=1):
                mini_header = iden.find_elements(By.CSS_SELECTOR, 'th')
                mini_headers = [mini.text for mini in mini_header]
                df_mini_header = pd.DataFrame(columns = mini_headers) # For each table, create a dataframe. Since some will be empty (for god knows why)....
                
                dataframes[f'df_{i}'] = df_mini_header #... let's try to include only those that are not empty ...
                df_table = [] #... and we fill the non-empty dataframe here
                for j in range(1, len(dataframes) + 1): 
                    if dataframes[f'df_{j}'].columns.size > 0:
                        df_table.append(dataframes[f'df_{j}'])
            
            ## Filling the Columns
            iterate = 0 # To note in which dataframe is the iteration in later on
            for tab in table:
                value = tab.find_elements(By.CSS_SELECTOR, 'td')
                values = [val.text for val in value]
                if values:  
                    # Get the current DataFrame to update
                    df = df_table[iterate]
                    
                    # Split values into chunks based on the number of columns in the DataFrame
                    num_columns = len(df.columns)
                    
                    # If there is literally empty column (not even '-'), fill with empty columns
                    if len(values) % num_columns != 0:
                        total_values = len(values)
                        required_values = (total_values // num_columns + 1) * num_columns # this line is fucking smart. fucking ai man
                        values += [''] * (required_values - total_values)
            
                    # Split the rows to fit into the dataframe
                    rows = [values[i:i + num_columns] for i in range(0, len(values), num_columns)]
                        
                    # Create a new DataFrame from the rows and append to the current DataFrame
                    df_new = pd.DataFrame(rows, columns=df.columns)
                    df_table[iterate] = pd.concat([df, df_new], ignore_index=True)
                    
                    # Move to the next DataFrame for the next set of values
                    iterate += 1
                
                # Break the loop if all DataFrames are populated
                if iterate >= len(df_table):
                    break
            
            ## Filling the Columns: jobs (inserted to df_table)
            for occ in table:
                job_info = occ.find_elements(By.TAG_NAME, 'h3') + occ.find_elements(By.TAG_NAME, 'p')
                jobs_info = [jobs.text.strip() for jobs in job_info]
                jobs = pd.DataFrame({jobs_info[0]:[jobs_info[1]]})
                df_table.append(jobs)
                if len(jobs_info)<=2:
                    break
            
            ## concatenate the df_table
            for i in range(0, len(df_table) - 1):
                if len(df_table[i])>1:
                    df_table[i] = pd.DataFrame({col: [', '.join(df_table[i][col])] for col in df_table[i].columns})
                else:
                    continue
            
            df_table = pd.concat(df_table, axis=1) 
            
            ############################## Final
            DPR_profile = pd.concat([df_profile, df_table], axis=1)
            DPR = pd.concat([DPR, DPR_profile], axis=1, join='outer')
            ################################################################ Profile Scraping ##################################################################
            
            # Back
            driver.back(); 
        except NoSuchElementException as private_profile: 
            continue
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[465], line 142
#     140 ############################## Final
#     141 DPR_profile = pd.concat([df_profile, df_table], axis=1)
# --> 142 DPR = pd.concat([DPR, DPR_profile])
#     143 ################################################################ Profile Scraping ##################################################################
#     144
#     145 # Back
#     146 driver.back();
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\reshape\concat.py:676, in _Concatenator.get_result(self)
#     674         obj_labels = obj.axes[1 - ax]
#     675         if not new_labels.equals(obj_labels):
# --> 676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
#     680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#
# File D:\Coding\Language Packages\Python\Lib\site-packages\pandas\core\indexes\base.py:3875, in Index.get_indexer(self, target, method, limit, tolerance)
#    3872 self._check_indexing_method(method, limit, tolerance)
#    3874 if not self._index_as_unique:
# -> 3875     raise InvalidIndexError(self._requires_unique_msg)
#    3877 if len(target) == 0:
#    3878     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
# Export #
DPR.to_excel('Scraping KPU 150824.xlsx', index=False)

# %% [markdown]
# Bugs:
# 1. In some profiles, nama lengkap, tempat, tanggal lahir is in the rightmost of the columns (due to the incomplete profile or different spellings/cases}. Additionally, those profiles also have several mismatched columns to row.
#
# Improvement:
# 1. Make it click more than 1 for faster scraping
